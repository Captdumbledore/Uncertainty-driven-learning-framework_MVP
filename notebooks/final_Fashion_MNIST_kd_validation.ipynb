# %% [markdown]
# # Final Fashion-MNIST Validation (Post-Audit)
#
# This notebook contains the **official post-audit experimental validation** of the Adaptive Knowledge Reasoning Module (AKRM) applied to the Fashion-MNIST dataset.
#
# The implementation used in this notebook corresponds to the **audited and stable MVP** version of the project. Prior to these experiments, the framework underwent an independent implementation audit to verify:
#
# - Data leakage
# - Evaluation leakage
# - Dataset split integrity
# - Experimental fairness
# - Random seed reproducibility
# - Knowledge Distillation implementation
# - AKRM reasoning pipeline
# - Hidden implementation bugs
#
# The identified issues were corrected before generating the results contained in this notebook.
#
# > **Official Experimental Record**
# >
# > The results produced in this notebook represent the **authoritative experimental results** for the current MVP implementation evaluated on Fashion-MNIST, and are the results reported throughout this repository.
# >
# > All experiments were executed using the audited implementation under identical experimental conditions across multiple random seeds to prove cross-dataset generalization.
#
# ---
#
# ## Experiment Configuration
#
# - **Framework:** Adaptive Knowledge Reasoning Module (AKRM)
# - **Dataset:** Fashion-MNIST
# - **Base Training:** 15 epochs
# - **Learning Protocol:** Knowledge Distillation
# - **MC Dropout Passes:** 30
# - **Top Uncertain Samples:** 10%
# - **Random Seeds:** 42, 123, 999
#
# ---
#
# ## Purpose
#
# The objective of this notebook is to evaluate whether uncertainty-guided knowledge gap reasoning, combined with Knowledge Distillation, successfully generalizes to a new dataset and improves generalization over conventional uncertainty-guided retraining while maintaining a fair and reproducible experimental protocol.
#
# The notebook executes the complete experimental pipeline from baseline training through uncertainty estimation, AKRM reasoning, retraining, and final evaluation, demonstrating that the framework's architecture is dataset-agnostic.
#
# ---
#
# ## Repository Note
#
# This notebook accompanies the stable MVP release of the project.
#
# The companion notebooks:
#
# - `final_cifar10_kd_validation.ipynb`
# - `learning_protocol_comparison.ipynb`
#
# document the primary CIFAR-10 validation and the research progression comparing multiple learning protocols explored during development.
#
# Together, these notebooks provide:
#
# - the evolution of the research methodology,
# - proof of cross-dataset generalization, and
# - the final experimentally validated implementation reported in this repository.

# %%
# Clone the repository and move into it
# !git clone https://github.com/Captdumbledore/Uncertainty-driven-learning-framework_MVP.git
# %cd Uncertainty-driven-learning-framework_MVP

# Install requirements
# !pip install -q -r requirements.txt

# Verify PyTorch and GPU
import torch
print(f'PyTorch: {torch.__version__}')
print(f'CUDA available: {torch.cuda.is_available()}')
if torch.cuda.is_available():
    print(f'GPU: {torch.cuda.get_device_name(0)}')
# Out:
# Cloning into 'Uncertainty-driven-learning-framework_MVP'...
# remote: Enumerating objects: 141, done.
# remote: Counting objects: 100% (141/141), done.
# remote: Compressing objects: 100% (104/104), done.
# remote: Total 141 (delta 47), reused 125 (delta 33), pack-reused 0 (from 0)
# Receiving objects: 100% (141/141), 31.45 MiB | 13.28 MiB/s, done.
# Resolving deltas: 100% (47/47), done.
# /content/Uncertainty-driven-learning-framework_MVP
# PyTorch: 2.11.0+cu128
# CUDA available: True
# GPU: Tesla T4

# %%
# !python main.py \
    --dataset FashionMNIST \
    --learning_protocol distillation \
    --epochs 15 \
    --retrain_epochs 8 \
    --mc_samples 30 \
    --top_fraction 0.10 \
    --seeds 42 123 999 \
    --output_dir outputs_fashionmnist
# Out:
# ...
#   UNCERTAINTY-GUIDED RETRAINING — RESEARCH PROTOTYPE
# ...
#   Dataset          : FashionMNIST
#   Initial epochs   : 15
#   Retraining epochs: 8
#   MC samples       : 30
#   Top fraction     : 10%
#   Seeds            : [42, 123, 999]
#   Device           : cuda
#   Output dir       : outputs_fashionmnist/
#
# ...
#   SEED: 42
# ...
#
#   --------------------------------------------------------------
#   Phase 1 — Loading data and training baseline CNN
#   --------------------------------------------------------------
# 100% 26.4M/26.4M [00:02<00:00, 11.4MB/s]
# 100% 29.5k/29.5k [00:00<00:00, 179kB/s]
# 100% 4.42M/4.42M [00:01<00:00, 3.34MB/s]
# 100% 5.15k/5.15k [00:00<00:00, 33.1MB/s]
#   Dataset     : FashionMNIST
#   Train size  : 54,000
#   Val size    : 6,000
#   Test size   : 10,000
#
#     Epoch  1/15  | Train Loss 0.5178  Acc 0.8095  | Val Loss 0.3663  Acc 0.8662
#     Epoch  2/15  | Train Loss 0.3416  Acc 0.8754  | Val Loss 0.2956  Acc 0.8892
# ...
